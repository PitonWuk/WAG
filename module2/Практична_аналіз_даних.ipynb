# %% [markdown]
# <a href="https://colab.research.google.com/github/PitonWuk/WAG/blob/main/module2/%D0%9F%D1%80%D0%B0%D0%BA%D1%82%D0%B8%D1%87%D0%BD%D0%B0_%D0%B0%D0%BD%D0%B0%D0%BB%D1%96%D0%B7_%D0%B4%D0%B0%D0%BD%D0%B8%D1%85.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Імпорт модулів та даних

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as pit

# %%
sales = pd.read_csv(
    'https://raw.githubusercontent.com/HalyshAnton/IT-Step-Pyton-AI/main/module2/data/bike_sales.csv',
    index_col = "Unnamed: 0",
    parse_dates=['Date'])

# %%
sales.head()
# Out:
#         Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0 2013-11-26   26  November  2013            19     Youth (<25)
# 1 2015-11-26   26  November  2015            19     Youth (<25)
# 2 2014-03-23   23     March  2014            49  Adults (35-64)
# 3 2016-03-23   23     March  2016            49  Adults (35-64)
# 4 2014-05-15   15       May  2014            47  Adults (35-64)
#
#   Customer_Gender    Country             State Product_Category Sub_Category  \
# 0               M     Canada  British Columbia      Accessories   Bike Racks
# 1               M     Canada  British Columbia      Accessories   Bike Racks
# 2               M  Australia   New South Wales      Accessories   Bike Racks
# 3               M  Australia   New South Wales      Accessories   Bike Racks
# 4               F  Australia   New South Wales      Accessories   Bike Racks
#
#                Product  Order_Quantity  Unit_Cost  Unit_Price  Profit  Cost  \
# 0  Hitch Rack - 4-Bike               8         45         120     590   360
# 1  Hitch Rack - 4-Bike               8         45         120     590   360
# 2  Hitch Rack - 4-Bike              23         45         120    1366  1035
# 3  Hitch Rack - 4-Bike              20         45         120    1188   900
# 4  Hitch Rack - 4-Bike               4         45         120     238   180
#
#    Revenue
# 0      950
# 1      950
# 2     2401
# 3     2088
# 4      418

# %% [markdown]
# # Завдання 1
# Виведіть середнє значення та медіану для `order_quantity`. Чи є викиди?

# %%
mean_order = sales['Order_Quantity'].mean()
median_order = sales['Order_Quantity'].median()
print(mean_order)
print(median_order)
# Out:
# 11.901659648253654
# 10.0

# %% [markdown]
# # Завдання 2
# Намалюйте гістограму та ящик з вусами для `order_quantity`

# %%
sales['Order_Quantity'].plot(kind='box', vert=False, figsize=(12, 6))
# Out:
# <Axes: >

# %%
ax = sales['Order_Quantity'].plot(kind='hist',
                             bins=20,
                             figsize=(14,6)
                             )

# %% [markdown]
# # Завдання 3
# Очистіть дані від викидів. Алгоритм:
#
# 1. Обчислюємо нижній `q1` та верхній `q3` квантилі
# 2. Обчислюємо медіану `median`
# 3. Очислюємо значення `IQR = q3 - q1`
# 4. Обчислюємо `lower = q1 - 1.5*IQR`
# 5. Обчислюємо `upper = q3 + 1.5*IQR`
# 6. Викидами вважаємо значення які `< lower` або `>upper`

# %%
def remove_outliers(df, column_name):
  column = df[column_name]

  q1 = column.quantile(q=0.25)
  q3 = column.quantile(q=0.75)

  iqr = q3 - q1

  lower = q1 - 1.5*iqr
  upper = q3 + 1.5*iqr

  mask = (column >= lower) & (column <= upper)

  return df[mask]

# %%
for column_name in sales.columns:
  if sales.dtypes[column_name] == 'object':
    continue

  sales = remove_outliers(sales, column_name)

# %%
sales['Order_Quantity'].plot(kind='box', vert=False, figsize=(14,6))
# Out:
# <Axes: >

# %% [markdown]
# # Завдання 4
# Ввиведіть гістограму з кількістю чоловіків та жінок серед покупців.

# %%
gender_counts = sales['Customer_Gender'].value_counts()
print(gender_counts)

ax = gender_counts.plot(kind='bar', figsize=(14,6))
# Out:
# M    27587
# F    26522
# Name: Customer_Gender, dtype: int64

# %% [markdown]
# # Завдання 5
# Виведіть точкову діаграму для ознак `order_quantity` та `revenue`

# %%
sales.plot(kind='scatter', x='Order_Quantity', y='Revenue', figsize=(6,6))
# Out:
# <Axes: xlabel='Order_Quantity', ylabel='Revenue'>

# %% [markdown]
# # Завдання 6
# Знайдіть категоріальну характеристику, від якої залежить ознака `profit`
